# %% [markdown]
# <a href="https://colab.research.google.com/github/kjghfnxggdgbvg/kjghfnxggdgbvg/blob/main/NN1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #*Dataset*

# %%
data = pd.read_csv('gas_turbines.csv')
data
# Out:
#            AT      AP      AH    AFDP    GTEP     TIT     TAT     TEY     CDP  \
# 0      6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  114.70  10.605
# 1      6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  114.72  10.598
# 2      6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  114.71  10.601
# 3      7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  114.72  10.606
# 4      7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  114.72  10.612
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 15034  9.0301  1005.6  98.460  3.5421  19.164  1049.7  546.21  111.61  10.400
# 15035  7.8879  1005.9  99.093  3.5059  19.414  1046.3  543.22  111.78  10.433
# 15036  7.2647  1006.3  99.496  3.4770  19.530  1037.7  537.32  110.19  10.483
# 15037  7.0060  1006.8  99.008  3.4486  19.377  1043.2  541.24  110.74  10.533
# 15038  6.9279  1007.2  97.533  3.4275  19.306  1049.9  545.85  111.58  10.583
#
#            CO     NOX
# ...

# %% [markdown]
# #*EDA*

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15039 entries, 0 to 15038
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AT      15039 non-null  float64
#  1   AP      15039 non-null  float64
#  2   AH      15039 non-null  float64
#  3   AFDP    15039 non-null  float64
#  4   GTEP    15039 non-null  float64
#  5   TIT     15039 non-null  float64
#  6   TAT     15039 non-null  float64
#  7   TEY     15039 non-null  float64
#  8   CDP     15039 non-null  float64
#  9   CO      15039 non-null  float64
#  10  NOX     15039 non-null  float64
# dtypes: float64(11)
# memory usage: 1.3 MB

# %% [markdown]
# *No missing value*

# %%
data.describe()
# Out:
#                  AT           AP            AH          AFDP          GTEP  \
# count  15039.000000  15039.00000  15039.000000  15039.000000  15039.000000
# mean      17.764381   1013.19924     79.124174      4.200294     25.419061
# std        7.574323      6.41076     13.793439      0.760197      4.173916
# min        0.522300    985.85000     30.344000      2.087400     17.878000
# 25%       11.408000   1008.90000     69.750000      3.723900     23.294000
# 50%       18.186000   1012.80000     82.266000      4.186200     25.082000
# 75%       23.862500   1016.90000     90.043500      4.550900     27.184000
# max       34.929000   1034.20000    100.200000      7.610600     37.402000
#
#                 TIT           TAT           TEY           CDP            CO  \
# count  15039.000000  15039.000000  15039.000000  15039.000000  15039.000000
# mean    1083.798770    545.396183    134.188464     12.102353      1.972499
# ...

# %% [markdown]
# *Duplicates*

# %%
data.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 15034    False
# 15035    False
# 15036    False
# 15037    False
# 15038    False
# Length: 15039, dtype: bool

# %% [markdown]
# *No dupliates*

# %% [markdown]
# outlier detection and distplot

# %%
sns.distplot(data.AT)

plt.show()

# %%
sns.distplot(data.AH)
# Out:
# <Axes: xlabel='AH', ylabel='Density'>

# %%
sns.distplot(data.AP)
# Out:
# <Axes: xlabel='AP', ylabel='Density'>

# %%
sns.distplot(data.AFDP)
# Out:
# <Axes: xlabel='AFDP', ylabel='Density'>

# %%
sns.distplot(data.GTEP)
# Out:
# <Axes: xlabel='GTEP', ylabel='Density'>

# %%
sns.distplot(data.TIT)
# Out:
# <Axes: xlabel='TIT', ylabel='Density'>

# %%
sns.distplot(data.TAT)
# Out:
# <Axes: xlabel='TAT', ylabel='Density'>

# %%
sns.distplot(data.CDP)
# Out:
# <Axes: xlabel='CDP', ylabel='Density'>

# %%
sns.distplot(data.CO)
# Out:
# <Axes: xlabel='CO', ylabel='Density'>

# %%
sns.distplot(data.NOX)
# Out:
# <Axes: xlabel='NOX', ylabel='Density'>

# %%
from sklearn.ensemble import IsolationForest

# %%
model = IsolationForest(contamination=0.01)

# %%
model.fit(data)
# Out:
# IsolationForest(contamination=0.01)

# %%
model.predict(data)
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
data_new = data.copy()

# %%
data['Anomaly'] = model.predict(data_new)

# %%
data.head()
# Out:
#        AT      AP      AH    AFDP    GTEP     TIT     TAT     TEY     CDP  \
# 0  6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  114.70  10.605
# 1  6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  114.72  10.598
# 2  6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  114.71  10.601
# 3  7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  114.72  10.606
# 4  7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  114.72  10.612
#
#        CO     NOX  Anomaly
# 0  3.1547  82.722        1
# 1  3.2363  82.776        1
# 2  3.2012  82.468        1
# 3  3.1923  82.670        1
# 4  3.2484  82.311        1

# %%
data[data['Anomaly'] == -1]
# Out:
#             AT      AP      AH    AFDP    GTEP     TIT     TAT     TEY  \
# 44      4.3930  1021.5  86.622  3.8506  21.467  1037.9  528.08  116.72
# 197     5.5817  1016.7  85.499  3.8489  21.035  1035.4  527.44  114.07
# 261     5.6602  1018.3  86.968  3.8404  21.079  1028.5  523.86  112.02
# 262     5.0232  1017.8  87.114  3.8648  21.435  1032.5  524.71  113.60
# 336     4.7494  1016.0  79.550  5.8497  36.816  1100.1  514.30  173.26
# ...        ...     ...     ...     ...     ...     ...     ...     ...
# 14588  15.3930  1021.7  81.204  3.3709  18.807  1033.8  536.84  104.88
# 14593  12.3620  1022.5  88.415  3.6979  21.238  1034.7  528.02  112.10
# 14855  10.6310  1007.1  95.055  3.3938  19.246  1026.1  531.18  105.36
# 14909   3.6984  1028.1  87.139  3.4336  19.777  1036.5  532.36  113.61
# 15019  12.3000  1009.1  78.523  3.4084  18.947  1023.9  530.12  104.23
#
#           CDP       CO      NOX  Anomaly
# 44     11.141  31.9710   99.229       -1
# ...

# %%
data.iloc[0:4].mean()
# Out:
# AT            6.899750
# AP         1008.575000
# AH           96.276250
# AFDP          3.490675
# GTEP         19.740500
# TIT        1059.375000
# TAT         549.965000
# TEY         114.712500
# CDP          10.602500
# CO            3.196125
# NOX          82.659000
# Anomaly       1.000000
# dtype: float64

# %% [markdown]
# *there are to many outliers*

# %%
data.drop('Anomaly',axis=1,inplace=True)

# %%
data
# Out:
#            AT      AP      AH    AFDP    GTEP     TIT     TAT     TEY     CDP  \
# 0      6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  114.70  10.605
# 1      6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  114.72  10.598
# 2      6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  114.71  10.601
# 3      7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  114.72  10.606
# 4      7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  114.72  10.612
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 15034  9.0301  1005.6  98.460  3.5421  19.164  1049.7  546.21  111.61  10.400
# 15035  7.8879  1005.9  99.093  3.5059  19.414  1046.3  543.22  111.78  10.433
# 15036  7.2647  1006.3  99.496  3.4770  19.530  1037.7  537.32  110.19  10.483
# 15037  7.0060  1006.8  99.008  3.4486  19.377  1043.2  541.24  110.74  10.533
# 15038  6.9279  1007.2  97.533  3.4275  19.306  1049.9  545.85  111.58  10.583
#
#            CO     NOX
# ...

# %%
x = data.drop('TEY', axis=1)
y = data[["TEY"]]

# %% [markdown]
# *features selection*

# %%
from numpy import set_printoptions
from sklearn.feature_selection import mutual_info_regression
from sklearn.feature_selection import SelectKBest

# %%
test = SelectKBest(score_func=mutual_info_regression, k='all')
fit = test.fit(x, y)

# %%
scores = fit.scores_
features = fit.transform(x)

# %%
score_data = pd.DataFrame(list(zip(scores, x.columns)), columns =['Score', 'Feature'])
score_data.sort_values(by="Score", ascending=False, inplace=True)
score_data
# Out:
#       Score Feature
# 7  1.712171     CDP
# 4  1.600679    GTEP
# 5  1.321746     TIT
# 6  0.895303     TAT
# 3  0.661225    AFDP
# 8  0.512969      CO
# 0  0.412221      AT
# 9  0.300616     NOX
# 1  0.137322      AP
# 2  0.097516      AH

# %%
score_data.sort_values('Score', ascending=False)
# Out:
#       Score Feature
# 7  1.712171     CDP
# 4  1.600679    GTEP
# 5  1.321746     TIT
# 6  0.895303     TAT
# 3  0.661225    AFDP
# 8  0.512969      CO
# 0  0.412221      AT
# 9  0.300616     NOX
# 1  0.137322      AP
# 2  0.097516      AH

# %%
model_data = data[['CDP', 'GTEP','TIT', 'TAT', 'AFDP', 'CO', 'AT',"TEY"]]
model_data.head()
# Out:
#       CDP    GTEP     TIT     TAT    AFDP      CO      AT     TEY
# 0  10.605  19.663  1059.2  550.00  3.5000  3.1547  6.8594  114.70
# 1  10.598  19.728  1059.3  550.00  3.4998  3.2363  6.7850  114.72
# 2  10.601  19.779  1059.4  549.87  3.4824  3.2012  6.8977  114.71
# 3  10.606  19.792  1059.6  549.99  3.4805  3.1923  7.0569  114.72
# 4  10.612  19.765  1059.7  549.98  3.4976  3.2484  7.3978  114.72

# %% [markdown]
# *Applying standard scaler*

# %%
np.random.seed(8)
X = data.drop(['TEY'],axis=1)
Y = data['TEY']
X
# Out:
#            AT      AP      AH    AFDP    GTEP     TIT     TAT     CDP      CO  \
# 0      6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  10.605  3.1547
# 1      6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  10.598  3.2363
# 2      6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  10.601  3.2012
# 3      7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  10.606  3.1923
# 4      7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  10.612  3.2484
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 15034  9.0301  1005.6  98.460  3.5421  19.164  1049.7  546.21  10.400  4.5186
# 15035  7.8879  1005.9  99.093  3.5059  19.414  1046.3  543.22  10.433  4.8470
# 15036  7.2647  1006.3  99.496  3.4770  19.530  1037.7  537.32  10.483  7.9632
# 15037  7.0060  1006.8  99.008  3.4486  19.377  1043.2  541.24  10.533  6.2494
# 15038  6.9279  1007.2  97.533  3.4275  19.306  1049.9  545.85  10.583  4.9816
#
#           NOX
# 0      82.722
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
a = StandardScaler()
a.fit(X)
X_standardized = a.transform(X)

# %%
Y
# Out:
# 0        114.70
# 1        114.72
# 2        114.71
# 3        114.72
# 4        114.72
#           ...
# 15034    111.61
# 15035    111.78
# 15036    110.19
# 15037    110.74
# 15038    111.58
# Name: TEY, Length: 15039, dtype: float64

# %%
# !pip install tensorflow

# %%
# !pip install keras

# %%
# !pip install patchify    #To install and import other mentioned libraries  in code
# !pip install segmentation_models

# %%
# !pip install scikeras

# %%
# !pip install keras-tuner --upgrade

# %%
from tensorflow import keras
from keras.layers import Dense
from keras.layers import Dropout
from keras.optimizers import Adam
from tensorflow.keras import layers
from keras.models import Sequential
from keras_tuner.tuners import RandomSearch
from scikeras.wrappers import KerasClassifier, KerasRegressor

# %% [markdown]
# *Optimal batchsize and no of epochs*

# %%
model = Sequential()
model.add(Dense(26, input_dim = 10,  activation='relu'))
model.add(Dense(26,  activation='tanh'))
model.add(Dense(26, activation='sigmoid'))
model.add(Dense(26, activation='leaky_relu'))

# %%
model.compile(loss='mse', optimizer='adam', metrics=['mean_absolute_percentage_error'])

# %%
history = model.fit(X, Y, validation_split=0.33, epochs=20, batch_size=10)
# Out:
# Epoch 1/20
# 1008/1008 [==============================] - 5s 4ms/step - loss: 14826.0723 - mean_absolute_percentage_error: 88.8478 - val_loss: 10897.1943 - val_mean_absolute_percentage_error: 77.9677
# Epoch 2/20
# 1008/1008 [==============================] - 3s 3ms/step - loss: 9216.6709 - mean_absolute_percentage_error: 69.3433 - val_loss: 6514.9580 - val_mean_absolute_percentage_error: 59.5243
# Epoch 3/20
# 1008/1008 [==============================] - 8s 8ms/step - loss: 5422.0684 - mean_absolute_percentage_error: 52.2607 - val_loss: 3549.8428 - val_mean_absolute_percentage_error: 42.8808
# Epoch 4/20
# 1008/1008 [==============================] - 8s 8ms/step - loss: 2893.5486 - mean_absolute_percentage_error: 36.8891 - val_loss: 1692.1490 - val_mean_absolute_percentage_error: 27.9855
# Epoch 5/20
# ...

# %%
scores = model.evaluate(X, Y)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]))
# Out:
# 470/470 [==============================] - 1s 2ms/step - loss: 252.1611 - mean_absolute_percentage_error: 8.9326
# mean_absolute_percentage_error: 8.93%

# %%
model.metrics_names
# Out:
# ['loss', 'mean_absolute_percentage_error']

# %%
scores
# Out:
# [252.16110229492188, 8.932596206665039]

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'mean_absolute_percentage_error', 'val_loss', 'val_mean_absolute_percentage_error'])

# %%
plt.plot(history.history['mean_absolute_percentage_error'])
plt.plot(history.history['val_mean_absolute_percentage_error'])
plt.title('model mean_absolute_percentage_error')
plt.ylabel('mean_absolute_percentage_error')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
